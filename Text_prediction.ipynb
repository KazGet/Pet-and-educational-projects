# %% [markdown]
# <a href="https://colab.research.google.com/github/KazGet/Laboratory-work/blob/main/Text_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import re

from tensorflow.keras.layers import Dense, SimpleRNN, Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.text import Tokenizer

with open('text.txt', 'r', encoding='utf-8') as f:
    text = f.read()
    text = text.replace('\ufeff', '')  # убираем первый невидимый символ
    text = re.sub(r'[^А-я ]', '', text)  # заменяем все символы кроме кириллицы на пустые символы

# парсим текст, как последовательность символов
num_characters = 34  # 33 буквы + пробел
tokenizer = Tokenizer(num_words=num_characters, char_level=True)  # токенизируем на уровне символов
tokenizer.fit_on_texts([text])  # формируем токены на основе частотности в нашем тексте
print(tokenizer.word_index)

inp_chars = 10
data = tokenizer.texts_to_matrix(text)  # преобразуем исходный текст в массив OHE
n = data.shape[0] - inp_chars  # так как мы предсказываем по трем символам - четвертый

X = np.array([data[i:i + inp_chars, :] for i in range(n)])
Y = data[inp_chars:]  # предсказание следующего символа

print(data.shape)

model = Sequential()
model.add(Input((inp_chars,
                 num_characters)))  # при тренировке в рекуррентные модели keras подается сразу вся последовательность, поэтому в input теперь два числа. 1-длина последовательности, 2-размер OHE
model.add(SimpleRNN(128, activation='tanh'))  # рекуррентный слой на 500 нейронов
model.add(Dense(num_characters, activation='softmax'))
model.summary()

model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

history = model.fit(X, Y, batch_size=32, epochs=100)
# Out:
# {' ': 1, 'о': 2, 'а': 3, 'и': 4, 'е': 5, 'н': 6, 'т': 7, 'л': 8, 'с': 9, 'в': 10, 'м': 11, 'р': 12, 'к': 13, 'д': 14, 'у': 15, 'ы': 16, 'я': 17, 'п': 18, 'з': 19, 'ь': 20, 'б': 21, 'ч': 22, 'х': 23, 'г': 24, 'ш': 25, 'й': 26, 'ж': 27, 'ю': 28, 'ц': 29, 'э': 30, 'ф': 31, 'щ': 32, 'ъ': 33}
# (8073, 34)
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_7 (SimpleRNN)    (None, 128)               20864
#
#  dense_7 (Dense)             (None, 34)                4386
#
# =================================================================
# Total params: 25250 (98.63 KB)
# Trainable params: 25250 (98.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 252/252 [==============================] - 3s 6ms/step - loss: 2.9957 - accuracy: 0.1703
# Epoch 2/100
# 252/252 [==============================] - 2s 8ms/step - loss: 2.6388 - accuracy: 0.2551
# Epoch 3/100
# 252/252 [==============================] - 2s 8ms/step - loss: 2.4205 - accuracy: 0.3062
# Epoch 4/100
# 252/252 [==============================] - 1s 6ms/step - loss: 2.2637 - accuracy: 0.3445
# Epoch 5/100
# 252/252 [==============================] - 2s 6ms/step - loss: 2.1506 - accuracy: 0.3738
# Epoch 6/100
# 252/252 [==============================] - 1s 6ms/step - loss: 2.0651 - accuracy: 0.3955
# Epoch 7/100
# 252/252 [==============================] - 1s 6ms/step - loss: 1.9916 - accuracy: 0.4151
# Epoch 8/100
# 252/252 [==============================] - 2s 6ms/step - loss: 1.9171 - accuracy: 0.4382
# Epoch 9/100
# 252/252 [==============================] - 1s 6ms/step - loss: 1.8547 - accuracy: 0.4518
# Epoch 10/100
# 252/252 [==============================] - 2s 7ms/step - loss: 1.7961 - accuracy: 0.4730
# Epoch 11/100
# 252/252 [==============================] - 2s 8ms/step - loss: 1.7327 - accuracy: 0.4894
# Epoch 12/100
# 252/252 [==============================] - 2s 7ms/step - loss: 1.6730 - accuracy: 0.5063
# Epoch 13/100
# 252/252 [==============================] - 1s 6ms/step - loss: 1.6151 - accuracy: 0.5247
# Epoch 14/100
# 252/252 [==============================] - 1s 5ms/step - loss: 1.5620 - accuracy: 0.5355
# Epoch 15/100
# 252/252 [==============================] - 1s 6ms/step - loss: 1.5013 - accuracy: 0.5544
# Epoch 16/100
# 252/252 [==============================] - 2s 7ms/step - loss: 1.4451 - accuracy: 0.5682
# Epoch 17/100
# 252/252 [==============================] - 2s 6ms/step - loss: 1.3880 - accuracy: 0.5851
# Epoch 18/100
# 252/252 [==============================] - 1s 6ms/step - loss: 1.3406 - accuracy: 0.5982
# Epoch 19/100
# 252/252 [==============================] - 2s 8ms/step - loss: 1.2771 - accuracy: 0.6192
# Epoch 20/100
# 252/252 [==============================] - 2s 9ms/step - loss: 1.2316 - accuracy: 0.6313
# Epoch 21/100
# 252/252 [==============================] - 1s 6ms/step - loss: 1.1807 - accuracy: 0.6442
# Epoch 22/100
# 252/252 [==============================] - 2s 7ms/step - loss: 1.1352 - accuracy: 0.6555
# Epoch 23/100
# 252/252 [==============================] - 1s 5ms/step - loss: 1.0921 - accuracy: 0.6739
# Epoch 24/100
# 252/252 [==============================] - 2s 6ms/step - loss: 1.0467 - accuracy: 0.6840
# Epoch 25/100
# 252/252 [==============================] - 2s 9ms/step - loss: 0.9952 - accuracy: 0.7025
# Epoch 26/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.9586 - accuracy: 0.7114
# Epoch 27/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.9230 - accuracy: 0.7262
# Epoch 28/100
# 252/252 [==============================] - 2s 9ms/step - loss: 0.8806 - accuracy: 0.7379
# Epoch 29/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.8480 - accuracy: 0.7479
# Epoch 30/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.8080 - accuracy: 0.7627
# Epoch 31/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.7648 - accuracy: 0.7742
# Epoch 32/100
# 252/252 [==============================] - 2s 6ms/step - loss: 0.7318 - accuracy: 0.7836
# Epoch 33/100
# 252/252 [==============================] - 1s 5ms/step - loss: 0.7130 - accuracy: 0.7889
# Epoch 34/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.6711 - accuracy: 0.8048
# Epoch 35/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.6581 - accuracy: 0.8095
# Epoch 36/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.6191 - accuracy: 0.8212
# Epoch 37/100
# 252/252 [==============================] - 2s 6ms/step - loss: 0.5997 - accuracy: 0.8277
# Epoch 38/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.5797 - accuracy: 0.8384
# Epoch 39/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.5570 - accuracy: 0.8411
# Epoch 40/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.5356 - accuracy: 0.8451
# Epoch 41/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.5002 - accuracy: 0.8591
# Epoch 42/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.4872 - accuracy: 0.8653
# Epoch 43/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.4829 - accuracy: 0.8623
# Epoch 44/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.4636 - accuracy: 0.8674
# Epoch 45/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.4458 - accuracy: 0.8718
# Epoch 46/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.4141 - accuracy: 0.8870
# Epoch 47/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.4190 - accuracy: 0.8825
# Epoch 48/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.4104 - accuracy: 0.8845
# Epoch 49/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.3968 - accuracy: 0.8917
# Epoch 50/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.3881 - accuracy: 0.8912
# Epoch 51/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.3725 - accuracy: 0.8979
# Epoch 52/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.3506 - accuracy: 0.9060
# Epoch 53/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.3618 - accuracy: 0.8978
# Epoch 54/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.3439 - accuracy: 0.9041
# Epoch 55/100
# 252/252 [==============================] - 1s 5ms/step - loss: 0.3309 - accuracy: 0.9122
# Epoch 56/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.3321 - accuracy: 0.9116
# Epoch 57/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.3198 - accuracy: 0.9119
# Epoch 58/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.3176 - accuracy: 0.9118
# Epoch 59/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.3020 - accuracy: 0.9184
# Epoch 60/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.3132 - accuracy: 0.9113
# Epoch 61/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.3105 - accuracy: 0.9114
# Epoch 62/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.2882 - accuracy: 0.9219
# Epoch 63/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.2964 - accuracy: 0.9149
# Epoch 64/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.3176 - accuracy: 0.9096
# Epoch 65/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.3000 - accuracy: 0.9164
# Epoch 66/100
# 252/252 [==============================] - 2s 6ms/step - loss: 0.2672 - accuracy: 0.9283
# Epoch 67/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.2610 - accuracy: 0.9299
# Epoch 68/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.2677 - accuracy: 0.9261
# Epoch 69/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.3018 - accuracy: 0.9118
# Epoch 70/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.2767 - accuracy: 0.9225
# Epoch 71/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.2670 - accuracy: 0.9241
# Epoch 72/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.2765 - accuracy: 0.9194
# Epoch 73/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.2479 - accuracy: 0.9304
# Epoch 74/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.2452 - accuracy: 0.9317
# Epoch 75/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.2547 - accuracy: 0.9307
# Epoch 76/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.2648 - accuracy: 0.9236
# Epoch 77/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.2603 - accuracy: 0.9272
# Epoch 78/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.2493 - accuracy: 0.9273
# Epoch 79/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.2504 - accuracy: 0.9283
# Epoch 80/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.2595 - accuracy: 0.9242
# Epoch 81/100
# 252/252 [==============================] - 2s 6ms/step - loss: 0.2512 - accuracy: 0.9297
# Epoch 82/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.2459 - accuracy: 0.9283
# Epoch 83/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.2421 - accuracy: 0.9318
# Epoch 84/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.2525 - accuracy: 0.9297
# Epoch 85/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.2501 - accuracy: 0.9232
# Epoch 86/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.2542 - accuracy: 0.9260
# Epoch 87/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.2443 - accuracy: 0.9309
# Epoch 88/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.2237 - accuracy: 0.9367
# Epoch 89/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.2316 - accuracy: 0.9338
# Epoch 90/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.2568 - accuracy: 0.9211
# Epoch 91/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.2278 - accuracy: 0.9339
# Epoch 92/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.2167 - accuracy: 0.9364
# Epoch 93/100
# 252/252 [==============================] - 1s 5ms/step - loss: 0.2200 - accuracy: 0.9382
# Epoch 94/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.2192 - accuracy: 0.9387
# Epoch 95/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.2370 - accuracy: 0.9305
# Epoch 96/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.2382 - accuracy: 0.9301
# Epoch 97/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.2373 - accuracy: 0.9297
# Epoch 98/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.2266 - accuracy: 0.9310
# Epoch 99/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.2511 - accuracy: 0.9247
# Epoch 100/100
# 252/252 [==============================] - 1s 5ms/step - loss: 0.2445 - accuracy: 0.9246

# %%
def buildPhrase(inp_str, str_len=50):
    for i in range(str_len):
        x = []
        for j in range(i, i + inp_chars):
            x.append(tokenizer.texts_to_matrix(inp_str[j]))  # преобразуем символы в One-Hot-encoding

        x = np.array(x)
        inp = x.reshape(1, inp_chars, num_characters)

        pred = model.predict(inp)  # предсказываем OHE четвертого символа
        d = tokenizer.index_word[pred.argmax(axis=1)[0]]  # получаем ответ в символьном представлении

        inp_str += d  # дописываем строку

    return inp_str


res = buildPhrase("программир")
print(res)
# Out:
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# программирования для машинного обучения могут анализировать
